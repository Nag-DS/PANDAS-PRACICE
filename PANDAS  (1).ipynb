# %% [markdown]
# # PANDAS PRACTICE

# %% [markdown]
# #### Nagendrababu

# %%
import numpy as np
import pandas as pd

# %%
sma=pd.read_csv("Standard_Metropolitan_Areas_Data-data.csv")

# %%
sma.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
sma.loc[0:5,['land_area', 'percent_city', 'percent_senior', 'physicians',
       'hospital_beds']] # it is usedfull for based required data that data only printed
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
# 5       2815          23.1             6.7        7340          16941

# %%
sma.iloc[:,:9] #this is last columns droped
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region
# 0        50.1      4083.9   72100       1
# ...

# %%
sma.iloc[:,9:] #this is only for last column print
# Out:
#     crime_rate
# 0        75.55
# 1        56.03
# 2        41.32
# 3        67.38
# 4        80.19
# ..         ...
# 94       70.66
# 95       36.36
# 96       60.16
# 97       36.33
# 98       68.76
#
# [99 rows x 1 columns]

# %%
sma.columns
# Out:
# Index(['land_area', 'percent_city', 'percent_senior', 'physicians',
#        'hospital_beds', 'graduates', 'work_force', 'income', 'region',
#        'crime_rate'],
#       dtype='object')

# %%
sma.info() #it is also called as data summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
sma.describe(include="all") #print categorical data and numerical data
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
sma.describe(include="float") #this is only for FLOAT64
# Out:
#        percent_city  percent_senior  graduates   work_force  crime_rate
# count     99.000000       99.000000  99.000000    99.000000   99.000000
# mean      42.518182        9.781818  54.463636   449.366667   55.643030
# std       17.348277        2.524547   7.773286   610.990885   13.470943
# min       13.400000        3.900000  30.300000    66.900000   23.320000
# 25%       30.100000        8.350000  50.250000   150.300000   46.115000
# 50%       39.500000        9.700000  54.000000   257.200000   56.060000
# 75%       52.600000       10.750000  58.300000   436.500000   63.860000
# max      100.000000       21.800000  72.800000  4083.900000   85.620000

# %%
sma.describe(include="int64") #this is only for INT64
# Out:
#           land_area    physicians  hospital_beds        income     region
# count     99.000000     99.000000      99.000000     99.000000  99.000000
# mean    2615.727273   1828.333333    6345.868687   6762.505051   2.494949
# std     3045.826210   3192.199763    9136.202716  10393.349660   1.013921
# min       47.000000    140.000000     481.000000    769.000000   1.000000
# 25%     1408.000000    459.000000    2390.000000   2003.000000   2.000000
# 50%     1951.000000    774.000000    3472.000000   3510.000000   3.000000
# 75%     2890.500000   1911.500000    6386.500000   6283.500000   3.000000
# max    27293.000000  25627.000000   69678.000000  72100.000000   4.000000

# %%
sma.tail()  #last 5 value
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 94       50.4       127.2    1452       4       70.66
# 95       30.3        80.6     769       3       36.36
# 96       70.7        93.2    1337       3       60.16
# 97       58.0        97.0    1589       1       36.33
# 98       55.1        66.9    1148       3       68.76

# %%
sorted_data1=sma["crime_rate"].sort_values(ascending=False) #this descending order

# %%
sorted_data1[:5]
# Out:
# 20    85.62
# 74    82.68
# 53    80.94
# 4     80.19
# 67    78.10
# Name: crime_rate, dtype: float64

# %%
sma.isna() #this is checking for any null value
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       False         False           False       False          False
# 1       False         False           False       False          False
# 2       False         False           False       False          False
# 3       False         False           False       False          False
# 4       False         False           False       False          False
# ..        ...           ...             ...         ...            ...
# 94      False         False           False       False          False
# 95      False         False           False       False          False
# 96      False         False           False       False          False
# 97      False         False           False       False          False
# 98      False         False           False       False          False
#
#     graduates  work_force  income  region  crime_rate
# 0       False       False   False   False       False
# ...

# %%
sma.isnull() #it is also same as the ISNA() it returns bool value
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       False         False           False       False          False
# 1       False         False           False       False          False
# 2       False         False           False       False          False
# 3       False         False           False       False          False
# 4       False         False           False       False          False
# ..        ...           ...             ...         ...            ...
# 94      False         False           False       False          False
# 95      False         False           False       False          False
# 96      False         False           False       False          False
# 97      False         False           False       False          False
# 98      False         False           False       False          False
#
#     graduates  work_force  income  region  crime_rate
# 0       False       False   False   False       False
# ...

# %% [markdown]
# ## 2nd  DATASET

# %%
exam=pd.read_csv("exam_scores.csv")

# %%
exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exam.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# ## 3rd DATASET

# %%
import pandas as pd
data1=pd.read_csv("titanic_data.csv")

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1['Age'].mean()
# Out:
# 29.69911764705882

# %%
data1['Age'].fillna(data1['Age'].mean(),inplace=True)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
